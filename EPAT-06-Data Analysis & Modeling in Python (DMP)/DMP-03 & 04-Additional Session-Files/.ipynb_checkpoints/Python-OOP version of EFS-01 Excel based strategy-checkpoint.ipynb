# %% [markdown]
# # Objective:
# 1. Tune parameters short_window and long_window to maximize profit
# 2. Learn signal generation

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
plt.rcParams['axes.grid'] = False
import seaborn as sns
sns.set_style("whitegrid", {'axes.grid' : False})

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import HTML
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
class CROSSOVER:
    ## class attribute: We can know the possible values for moving_average and metrics 
    ## before creating an object of the class 
    moving_average = ("Simple","exponential") 
    metrics = {'Sharpe':'Sharpe Ratio',
               'CAGR':'Compound Average Growth Rate',
               'MDD':'Maximum Drawdown',
               'NHR':'Normalized Hit Ratio',
               'OTS':'Optimal trade size'}
    
    def __init__(self,data,short_window = 5, long_window = 40,
                 moving_average = "Simple", data_name = None, start = None,end = None ):

        """
         Doc string of the class. We define what class is about here
        """
        self.data=data #the dataframe
        self.data['yr'] = self.data['Date'].dt.year
        self.moving_average = moving_average
        if data_name is None:#the name that will appear on plots
            self.data_name = moving_average
        else:
            self.data_name=data_name
        self.short_window = short_window
        self.long_window = long_window
        self.n_days = (self.data.Date.iloc[-1] - self.data.Date.iloc[0])
        self.start=start #the beginning date of the sample period
        self.end=end #the ending date of the sample period

    def generate_signals(self, charts=True, burn=False):
        """
        This is an instance method. Only works on an object.
        """
        if self.long_window <= self.short_window: return

        if self.moving_average == "Simple":
            self.data["SMA"] = self.data.Close.rolling(self.short_window).mean()
            self.data["LMA"] = self.data.Close.rolling(self.long_window).mean()
        elif self.moving_average == "exponential":
            self.data["SMA"] = self.data.Close.ewm(span = self.short_window, adjust=True).mean()
            self.data["LMA"] = self.data.Close.ewm(span = self.long_window, adjust=True).mean()
        else:
            raise Exception("Not a valid type")

        self.data["_lag1_SMA"] = self.data.SMA.shift(1)
        self.data["_lag1_LMA"] = self.data.LMA.shift(1)

        ## creating signal    
        buy_mask = (self.data.SMA > self.data.LMA) & (self.data._lag1_SMA < self.data._lag1_LMA)
        sell_mask = (self.data.SMA < self.data.LMA) & (self.data._lag1_SMA > self.data._lag1_LMA)

        self.data['signal'] = np.nan
        self.data.loc[buy_mask,'signal'] = +1
        self.data.loc[sell_mask,'signal'] = -1
        if burn:
            burn_period = 2*self.long_window
            self.data.loc[:burn_period,"signal"] = np.nan
        self.data.signal = self.data.signal.fillna(method="ffill")

        mask = (self.data.signal != self.data.signal.shift(1)) & (self.data.signal.notnull())
        self.data['trade_num'] = np.where(mask,1,0).cumsum()

        ## display chart
        if charts:
            plt.plot(self.data['Date'],self.data['SMA'],color='black', label=f'SMA ={self.short_window}')
            plt.plot(self.data['Date'],self.data['LMA'],color='blue', label=f'LMA ={self.long_window}')
            plt.title('%s Strategy Backtest'%(self.data_name))
            plt.legend(loc=0)
            d_color = {}
            d_color[1] = '#90ee90'  ## light green
            d_color[-1] = "#ffcccb" ## light red

            j = 0
            for i in range(1,self.data.shape[0]):
                if np.isnan(self.data.signal[i-1]):
                    j=i
                elif (self.data.signal[i-1] == self.data.signal[i]) and (i< (self.data.shape[0]-1)):
                    continue
                else:
                    plt.axvspan(self.data['Date'][j], self.data['Date'][i], 
                               alpha=0.5, color=d_color[self.data.signal[i-1]], label="interval")
                    j = i
            plt.show()
        
    def signal_performance(self, allocation):
        """
        Another instance method
        """
        if self.long_window <= self.short_window: return
        self.allocation=allocation

        #creating returns and portfolio value series
        self.data['Return']=np.log(self.data['Close']/self.data['Close'].shift(1))
        self.data['S_Return']=self.data['signal'].shift(1)*self.data['Return']
        self.data['Market_Return']=self.data['Return'].expanding().sum()
        self.data['Strategy_Return']=self.data['S_Return'].expanding().sum()
        self.data['Portfolio Value']=((self.data['Strategy_Return']+1)*self.allocation)
        self.data['Wins']=np.where(self.data['S_Return'] > 0,1,0)
        self.data['Losses']=np.where(self.data['S_Return']<0,1,0)

        ## Daywise Performance
        d_perform = {}
        d_perform['TotalWins']=self.data['Wins'].sum()
        d_perform['TotalLosses']=self.data['Losses'].sum()
        d_perform['TotalTrades']=d_perform['TotalWins']+d_perform['TotalLosses']
        d_perform['HitRatio']=round(d_perform['TotalWins']/d_perform['TotalTrades'],2)
        d_perform['SharpeRatio'] = self.data["S_Return"].mean() / self.data["S_Return"].std() * (252**.5)        
        d_perform['CAGR'] = (1+self.data['Strategy_Return']).iloc[-1]**(365.25/self.n_days.days) -1
        d_perform['MaxDrawdown']=(1.0-self.data['Portfolio Value']/self.data['Portfolio Value'].cummax()).max()
        self.daywise_performance = pd.Series(d_perform)

        ## Tradewise performance
        _df = self.data.groupby(["signal","trade_num"]).S_Return.sum().reset_index()
        _df['Wins']=np.where(_df['S_Return'] > 0,1,0)
        _df['Losses']=np.where(_df['S_Return']<0,1,0)
        d_tp = {}
        d_tp.update(_df[["Wins","Losses"]].sum().rename({'Wins':'TotalWins','Losses':'TotalLosses'}).to_dict())
        d_tp['TotalTrades'] = d_tp["TotalWins"] + d_tp["TotalLosses"]
        d_tp['HitRatio'] =  np.round(d_tp["TotalWins"] / d_tp['TotalTrades'],4)
        d_tp['AvgWinRet'] = np.round(_df[_df.Wins==1].S_Return.mean(),4)
        d_tp['AvgLossRet'] = np.round(_df[_df.Losses==1].S_Return.mean(),4)
        d_tp['WinByLossRet'] = np.round(abs(d_tp['AvgWinRet']/d_tp['AvgLossRet']),2)
        d_tp['RetVar'] = np.round(_df.S_Return.std(),4)
        _sum = _df.groupby("Wins").S_Return.sum()
        d_tp['NormHitRatio'] = np.round(_sum[1]/_sum.abs().sum(),4)
        d_tp['OptimalTradeSize'] = self.kelly(p = d_tp['HitRatio'], b = d_tp['WinByLossRet'])
        self.tradewise_performance = pd.Series(d_tp)

    @staticmethod
    def kelly(p,b):
        """
        Static method: No object or class related arguments
        p: win prob, b: net odds received on wager, output(f*) = p - (1-p)/b

        Spreadsheet example
            from sympy import symbols, solve, diff
            x = symbols('x')
            y = (1+3.3*x)**37 *(1-x)**63
            solve(diff(y, x), x)[1]
        Shortcut
            .37 - 0.63/3.3
        """
        return np.round(p - (1-p)/b,4)

    def plot_performance(self, allocation=1):
        #intializing a variable for initial allocation
        #to be used to create equity curve
        self.signal_performance(allocation)
        
        #yearly performance
        self.yearly_performance()
        
        #Plotting the Performance of the strategy
        plt.plot(self.data['Date'],self.data['Market_Return'],color='black', label='Market Returns')
        plt.plot(self.data['Date'],self.data['Strategy_Return'],color='blue', label= 'Strategy Returns')
        plt.title('%s Strategy Backtest'%(self.data_name))
        plt.legend(loc=0)
        plt.tight_layout()
        plt.show()

        plt.plot(self.data['Date'],self.data['Portfolio Value'], color='blue')
        plt.title('%s Portfolio Value'%(self.data_name))
        plt.show()
        
    def yearly_performance(self):
        """
        Instance method
        Adds an instance attribute: yearly_df
        """
        _yearly_df = self.data.groupby(['yr','signal']).S_Return.sum().unstack()
        _yearly_df.rename(columns={-1.0:'Sell',1.0:'Buy'}, inplace=True)
        _yearly_df['Return'] = _yearly_df.sum(1)

        # yearly_df
        self.yearly_df = _yearly_df.style.bar(color=["#ffcccb",'#90ee90'], align = 'zero').format({
            'Sell': '{:,.2%}'.format,'Buy': '{:,.2%}'.format,'Return': '{:,.2%}'.format})
    
    def update_metrics(self):
        """
        Called from the SMA_LMA_matrix class method
        """
        d_field = {}
        if self.long_window > self.short_window:
            d_field['Sharpe'] = self.daywise_performance.SharpeRatio
            d_field['CAGR'] = self.daywise_performance.CAGR
            d_field['MDD'] = self.daywise_performance.MaxDrawdown
            d_field['NHR'] = self.tradewise_performance.NormHitRatio
            d_field['OTS'] = self.tradewise_performance.OptimalTradeSize
            
        return d_field
    
    @classmethod
    def SMA_LMA_matrix(cls,data, LMA_range, SMA_range, metrics, moving_average = "Simple", optimal_sol = True):
        """
        This is a class method. First argument is a class.
        """
        c_green = sns.light_palette("green", as_cmap=True)
        c_red = sns.light_palette("red", as_cmap=True)
        
        d_mats = {m:[] for m in metrics}
        
        for l in LMA_range:
            d_row = {m:[] for m in metrics}
            for s in SMA_range:
                obj = cls(data, s, l, moving_average) ## object being created from the class
                obj.generate_signals(charts=False)
                obj.signal_performance(100)
                d_field = obj.update_metrics()
                for m in metrics: d_row[m].append(d_field.get(m,np.nan))
            for m in metrics: d_mats[m].append(d_row[m])
                
        d_df = {m:pd.DataFrame(d_mats[m], index=LMA_range, columns=SMA_range) for m in metrics}

        def optimal(_df):
            """ 
            This is a function inside a function.
            We could have created it outside the class if needed, but that would made it harder to relate. 
            """
            _df = _df.stack().rank()
            _df = (_df - _df.mean())/_df.std()
            return _df.unstack()

        if optimal_sol:
            d_df['Signal'] = 0
            if 'Sharpe' in metrics: d_df['Signal'] += 2*optimal(d_df['Sharpe'])
            if 'NHR' in metrics: d_df['Signal'] += optimal(d_df['NHR'])
            if 'CAGR' in metrics: d_df['Signal'] += optimal(d_df['CAGR'])
            if 'MDD' in metrics: d_df['Signal'] -= 2*optimal(d_df['MDD'])
            l_i,s_i = np.unravel_index(np.argmax(d_df['Signal'].values), d_df['Signal'].shape)
            print(f"Most optimal cross-over pair is SMA:{SMA_range[s_i]}, LMA:{LMA_range[l_i]}")
            metrics.insert(0,'Signal')

        for m in metrics:
            display(HTML(d_df[m].style.background_gradient(axis=None, cmap=
                c_red if m=="MDD" else c_green).format(
                ("{:,.2}" if m in ["Sharpe","Signal"] else "{:.2%}")).set_caption(m).render()))
            
        return d_df

# %%
close_df = pd.read_csv("class_data.csv", parse_dates = [0])

# %%
close_df.head()
# Out:
#         Date   Close
# 0 2000-01-03  1592.2
# 1 2000-01-04  1638.7
# 2 2000-01-05  1595.8
# 3 2000-01-06  1617.6
# 4 2000-01-07  1613.3

# %%
close_df.shape
# Out:
# (4235, 2)

# %%
close_df.head()
# Out:
#         Date   Close
# 0 2000-01-03  1592.2
# 1 2000-01-04  1638.7
# 2 2000-01-05  1595.8
# 3 2000-01-06  1617.6
# 4 2000-01-07  1613.3

# %%
close_df.tail()
# Out:
#            Date    Close
# 4230 2016-12-26  7908.25
# 4231 2016-12-27  8032.85
# 4232 2016-12-28  8034.85
# 4233 2016-12-29  8103.60
# 4234 2016-12-30  8185.80

# %%
# close_df.Close.ewm(span = 20, adjust=False, min_periods=20).mean()

# %%
CROSSOVER.metrics
# Out:
# {'Sharpe': 'Sharpe Ratio',
#  'CAGR': 'Compound Average Growth Rate',
#  'MDD': 'Maximum Drawdown',
#  'NHR': 'Normalized Hit Ratio',
#  'OTS': 'Optimal trade size'}

# %%
CROSSOVER.moving_average
# Out:
# ('Simple', 'exponential')

# %%
## Possible values for metrics : 'Sharpe','CAGR','MDD','NHR','OTS'
_ = CROSSOVER.SMA_LMA_matrix(close_df, SMA_range=range(9,44,5), LMA_range=range(40,120,5),
                             metrics = ['CAGR','MDD','Sharpe'], moving_average='Simple')
# Out:
# Most optimal cross-over pair is SMA:24, LMA:90
# <style  type="text/css" >
#     #T_7ff145e0_8712_11eb_b140_f218982abb7brow0_col0 {
#             background-color:  #1e901e;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow0_col1 {
#             background-color:  #239323;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow0_col2 {
#             background-color:  #a0d9a0;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow0_col3 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow0_col4 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow0_col5 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow0_col6 {
#             background-color:  #98d498;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow1_col0 {
#             background-color:  #178d17;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow1_col1 {
#             background-color:  #8acc8a;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow1_col2 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow1_col3 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow1_col4 {
#             background-color:  #d4f6d4;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow1_col5 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow1_col6 {
#             background-color:  #97d497;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow2_col0 {
#             background-color:  #52ad52;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow2_col1 {
#             background-color:  #88cb88;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow2_col2 {
#             background-color:  #c4edc4;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow2_col3 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow2_col4 {
#             background-color:  #c6eec6;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow2_col5 {
#             background-color:  #b4e4b4;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow2_col6 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow3_col0 {
#             background-color:  #4eab4e;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow3_col1 {
#             background-color:  #81c781;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow3_col2 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow3_col3 {
#             background-color:  #8cce8c;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow3_col4 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow3_col5 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow3_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow4_col0 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow4_col1 {
#             background-color:  #9ed89e;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow4_col2 {
#             background-color:  #a2daa2;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow4_col3 {
#             background-color:  #7ec67e;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow4_col4 {
#             background-color:  #84c984;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow4_col5 {
#             background-color:  #b5e4b5;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow4_col6 {
#             background-color:  #ddfbdd;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow5_col0 {
#             background-color:  #299729;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow5_col1 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow5_col2 {
#             background-color:  #61b661;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow5_col3 {
#             background-color:  #59b159;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow5_col4 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow5_col5 {
#             background-color:  #9ad59a;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow5_col6 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow6_col0 {
#             background-color:  #289628;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow6_col1 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow6_col2 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow6_col3 {
#             background-color:  #6fbd6f;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow6_col4 {
#             background-color:  #7fc67f;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow6_col5 {
#             background-color:  #88cb88;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow6_col6 {
#             background-color:  #9dd79d;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow7_col0 {
#             background-color:  #1f911f;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow7_col1 {
#             background-color:  #51ad51;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow7_col2 {
#             background-color:  #60b560;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow7_col3 {
#             background-color:  #50ac50;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow7_col4 {
#             background-color:  #45a645;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow7_col5 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow7_col6 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow8_col0 {
#             background-color:  #2f9a2f;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow8_col1 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow8_col2 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_7ff145e0_8712_11eb_b140_f218982abb7brow8_col3 {
#             background-color:  #59b159;
#             color:  #000000;
# <style  type="text/css" >
#     #T_7ff8b35c_8712_11eb_b140_f218982abb7brow0_col0 {
#             background-color:  #058305;
#             color:  #f1f1f1;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow0_col1 {
#             background-color:  #148b14;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow0_col2 {
#             background-color:  #79c379;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow0_col3 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow0_col4 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow0_col5 {
#             background-color:  #7ac37a;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow0_col6 {
#             background-color:  #4aa94a;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow1_col0 {
#             background-color:  #068306;
#             color:  #f1f1f1;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow1_col1 {
#             background-color:  #55af55;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow1_col2 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow1_col3 {
#             background-color:  #c1ebc1;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow1_col4 {
#             background-color:  #bae7ba;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow1_col5 {
#             background-color:  #abdfab;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow1_col6 {
#             background-color:  #48a848;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow2_col0 {
#             background-color:  #1f911f;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow2_col1 {
#             background-color:  #5bb25b;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow2_col2 {
#             background-color:  #80c780;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow2_col3 {
#             background-color:  #79c379;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow2_col4 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow2_col5 {
#             background-color:  #7ac47a;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow2_col6 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow3_col0 {
#             background-color:  #2b982b;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow3_col1 {
#             background-color:  #4daa4d;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow3_col2 {
#             background-color:  #7fc67f;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow3_col3 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow3_col4 {
#             background-color:  #4caa4c;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow3_col5 {
#             background-color:  #92d192;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow3_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow4_col0 {
#             background-color:  #259425;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow4_col1 {
#             background-color:  #6abb6a;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow4_col2 {
#             background-color:  #6cbc6c;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow4_col3 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow4_col4 {
#             background-color:  #68ba68;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow4_col5 {
#             background-color:  #83c983;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow4_col6 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow5_col0 {
#             background-color:  #239323;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow5_col1 {
#             background-color:  #4ba94b;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow5_col2 {
#             background-color:  #3ca13c;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow5_col3 {
#             background-color:  #47a747;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow5_col4 {
#             background-color:  #a8dda8;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow5_col5 {
#             background-color:  #6dbc6d;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow5_col6 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow6_col0 {
#             background-color:  #239323;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow6_col1 {
#             background-color:  #3ba13b;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow6_col2 {
#             background-color:  #3da23d;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow6_col3 {
#             background-color:  #50ac50;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow6_col4 {
#             background-color:  #55af55;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow6_col5 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow6_col6 {
#             background-color:  #7ac37a;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow7_col0 {
#             background-color:  #108910;
#             color:  #f1f1f1;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow7_col1 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow7_col2 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow7_col3 {
#             background-color:  #42a442;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow7_col4 {
#             background-color:  #42a442;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow7_col5 {
#             background-color:  #4ba94b;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow7_col6 {
#             background-color:  #57b057;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow8_col0 {
#             background-color:  #118911;
#             color:  #f1f1f1;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow8_col1 {
#             background-color:  #379e37;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow8_col2 {
#             background-color:  #289628;
#             color:  #000000;
#         }    #T_7ff8b35c_8712_11eb_b140_f218982abb7brow8_col3 {
#             background-color:  #48a848;
#             color:  #000000;
# <style  type="text/css" >
#     #T_80002d3a_8712_11eb_b140_f218982abb7brow0_col0 {
#             background-color:  #ffa6a6;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow0_col1 {
#             background-color:  #ffa9a9;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow0_col2 {
#             background-color:  #ff9393;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow0_col3 {
#             background-color:  #ff3b3b;
#             color:  #f1f1f1;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow0_col4 {
#             background-color:  #ff4040;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow0_col5 {
#             background-color:  #ff3737;
#             color:  #f1f1f1;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow0_col6 {
#             background-color:  #ff6a6a;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow1_col0 {
#             background-color:  #ffb0b0;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow1_col1 {
#             background-color:  #ff9494;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow1_col2 {
#             background-color:  #ff8b8b;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow1_col3 {
#             background-color:  #ff3d3d;
#             color:  #f1f1f1;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow1_col4 {
#             background-color:  #ff4848;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow1_col5 {
#             background-color:  #ff5757;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow1_col6 {
#             background-color:  #ff5e5e;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow2_col0 {
#             background-color:  #ff8080;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow2_col1 {
#             background-color:  #ff9e9e;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow2_col2 {
#             background-color:  #ff4e4e;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow2_col3 {
#             background-color:  #ff8080;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow2_col4 {
#             background-color:  #ff5e5e;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow2_col5 {
#             background-color:  #ff7474;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow2_col6 {
#             background-color:  #ff4b4b;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow3_col0 {
#             background-color:  #ff9c9c;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow3_col1 {
#             background-color:  #ff9696;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow3_col2 {
#             background-color:  #ff2a2a;
#             color:  #f1f1f1;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow3_col3 {
#             background-color:  #ff9b9b;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow3_col4 {
#             background-color:  #ff8d8d;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow3_col5 {
#             background-color:  #ff6f6f;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow3_col6 {
#             background-color:  #ff2d2d;
#             color:  #f1f1f1;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow4_col0 {
#             background-color:  #ffc4c4;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow4_col1 {
#             background-color:  #ff8b8b;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow4_col2 {
#             background-color:  #ff8989;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow4_col3 {
#             background-color:  #ffbbbb;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow4_col4 {
#             background-color:  #ffacac;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow4_col5 {
#             background-color:  #ff8282;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow4_col6 {
#             background-color:  #ff3838;
#             color:  #f1f1f1;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow5_col0 {
#             background-color:  #ffc3c3;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow5_col1 {
#             background-color:  #ff8484;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow5_col2 {
#             background-color:  #ffa2a2;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow5_col3 {
#             background-color:  #ffc6c6;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow5_col4 {
#             background-color:  #ff7474;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow5_col5 {
#             background-color:  #ff9494;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow5_col6 {
#             background-color:  #ff5858;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow6_col0 {
#             background-color:  #ffbebe;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow6_col1 {
#             background-color:  #ff9494;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow6_col2 {
#             background-color:  #ff9292;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow6_col3 {
#             background-color:  #ffbcbc;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow6_col4 {
#             background-color:  #ffa3a3;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow6_col5 {
#             background-color:  #ffacac;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow6_col6 {
#             background-color:  #ff9494;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow7_col0 {
#             background-color:  #ffa7a7;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow7_col1 {
#             background-color:  #ff9e9e;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow7_col2 {
#             background-color:  #ffaaaa;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow7_col3 {
#             background-color:  #ffcdcd;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow7_col4 {
#             background-color:  #ffdbdb;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow7_col5 {
#             background-color:  #ffcaca;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow7_col6 {
#             background-color:  #ffc2c2;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow8_col0 {
#             background-color:  #ff9393;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow8_col1 {
#             background-color:  #ff5959;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow8_col2 {
#             background-color:  #ffabab;
#             color:  #000000;
#         }    #T_80002d3a_8712_11eb_b140_f218982abb7brow8_col3 {
#             background-color:  #ffcccc;
#             color:  #000000;
# <style  type="text/css" >
#     #T_8008a000_8712_11eb_b140_f218982abb7brow0_col0 {
#             background-color:  #0f880f;
#             color:  #f1f1f1;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow0_col1 {
#             background-color:  #269526;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow0_col2 {
#             background-color:  #9cd69c;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow0_col3 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow0_col4 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow0_col5 {
#             background-color:  #9cd69c;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow0_col6 {
#             background-color:  #6bbb6b;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow1_col0 {
#             background-color:  #118911;
#             color:  #f1f1f1;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow1_col1 {
#             background-color:  #78c278;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow1_col2 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow1_col3 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow1_col4 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow1_col5 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow1_col6 {
#             background-color:  #69ba69;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow2_col0 {
#             background-color:  #379e37;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow2_col1 {
#             background-color:  #7fc67f;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow2_col2 {
#             background-color:  #a2daa2;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow2_col3 {
#             background-color:  #9bd69b;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow2_col4 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow2_col5 {
#             background-color:  #9dd79d;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow2_col6 {
#             background-color:  #c6eec6;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow3_col0 {
#             background-color:  #42a442;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow3_col1 {
#             background-color:  #6cbc6c;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow3_col2 {
#             background-color:  #a1d9a1;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow3_col3 {
#             background-color:  #83c983;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow3_col4 {
#             background-color:  #6ebd6e;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow3_col5 {
#             background-color:  #b0e2b0;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow3_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow4_col0 {
#             background-color:  #3aa03a;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow4_col1 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow4_col2 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow4_col3 {
#             background-color:  #89cc89;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow4_col4 {
#             background-color:  #8cce8c;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow4_col5 {
#             background-color:  #a5dba5;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow4_col6 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow5_col0 {
#             background-color:  #379e37;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow5_col1 {
#             background-color:  #69ba69;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow5_col2 {
#             background-color:  #59b159;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow5_col3 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow5_col4 {
#             background-color:  #c1ebc1;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow5_col5 {
#             background-color:  #90d090;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow5_col6 {
#             background-color:  #c6eec6;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow6_col0 {
#             background-color:  #369e36;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow6_col1 {
#             background-color:  #57b057;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow6_col2 {
#             background-color:  #59b159;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow6_col3 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow6_col4 {
#             background-color:  #75c175;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow6_col5 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow6_col6 {
#             background-color:  #9ad59a;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow7_col0 {
#             background-color:  #1b8f1b;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow7_col1 {
#             background-color:  #45a645;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow7_col2 {
#             background-color:  #5cb35c;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow7_col3 {
#             background-color:  #5eb45e;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow7_col4 {
#             background-color:  #5eb45e;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow7_col5 {
#             background-color:  #69ba69;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow7_col6 {
#             background-color:  #78c278;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow8_col0 {
#             background-color:  #1d901d;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow8_col1 {
#             background-color:  #52ad52;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow8_col2 {
#             background-color:  #3ea23e;
#             color:  #000000;
#         }    #T_8008a000_8712_11eb_b140_f218982abb7brow8_col3 {
#             background-color:  #67b967;
#             color:  #000000;

# %%
ema_strategy = CROSSOVER(close_df, moving_average='Simple', short_window =24, long_window = 90) ## Best drawdown
ema_strategy.generate_signals()

# %%
ema_strategy = CROSSOVER(close_df, moving_average='Simple', short_window =35, long_window = 105) ## Best CAGR
ema_strategy.generate_signals()

# %%
ema_strategy = CROSSOVER(close_df, moving_average='exponential', short_window =19, long_window = 45) ## Best Sharpe
ema_strategy.generate_signals()

# %%
# ema_strategy.data.sample(3).T

# %%
ema_strategy.plot_performance(100)

# %%
ema_strategy.daywise_performance
# Out:
# TotalWins      2166.000000
# TotalLosses    2057.000000
# TotalTrades    4223.000000
# HitRatio          0.510000
# SharpeRatio       0.483220
# CAGR              0.065596
# MaxDrawdown       0.452191
# dtype: float64

# %%
ema_strategy.tradewise_performance
# Out:
# TotalWins           32.0000
# TotalLosses         41.0000
# TotalTrades         73.0000
# HitRatio             0.4384
# AvgWinRet            0.1201
# AvgLossRet          -0.0463
# WinByLossRet         2.5900
# RetVar               0.1233
# NormHitRatio         0.6692
# OptimalTradeSize     0.2216
# dtype: float64

# %%
ema_strategy.yearly_df
# Out:
# <style  type="text/css" >
#     #T_553edd34_4aaa_11eb_b329_f218982abb7brow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 50.5%, transparent 50.5%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 18.1%, #ffcccb 18.1%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 18.3%, #ffcccb 18.3%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 78.3%, transparent 78.3%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 55.9%, transparent 55.9%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 78.8%, transparent 78.8%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 57.4%, transparent 57.4%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 62.0%, transparent 62.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 68.0%, transparent 68.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.6%, #ffcccb 49.6%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 100.0%, transparent 100.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 100.0%, transparent 100.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 50.3%, transparent 50.3%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 63.9%, transparent 63.9%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 64.3%, transparent 64.3%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.0%, #ffcccb 37.0%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 70.2%, transparent 70.2%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 59.8%, transparent 59.8%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 52.0%, transparent 52.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 78.6%, transparent 78.6%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 80.4%, transparent 80.4%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.3%, #ffcccb 43.3%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 73.8%, transparent 73.8%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 68.5%, transparent 68.5%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 100.0%, transparent 100.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.9%, #ffcccb 12.9%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 53.1%, transparent 53.1%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.1%, #ffcccb 49.1%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 92.7%, transparent 92.7%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 92.2%, transparent 92.2%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.8%, #ffcccb 38.8%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 52.9%, transparent 52.9%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.8%, #ffcccb 43.8%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_553edd34_4aaa_11eb_b329_f218982abb7brow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 57.0%, transparent 57.0%);
#         }    #T_5
