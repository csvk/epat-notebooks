# %% [markdown]
# # Objective:
# 1. Tune parameters short_window and long_window to maximize profit
# 2. Learn signal generation

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
plt.rcParams['axes.grid'] = False
import seaborn as sns
sns.set_style("whitegrid", {'axes.grid' : False})

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import HTML
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
class CROSSOVER:
    ## class attribute: We can know the possible values for moving_average and metrics 
    ## before creating an object of the class 
    moving_average = ("Simple","exponential") 
    metrics = {'Sharpe':'Sharpe Ratio',
               'CAGR':'Compound Average Growth Rate',
               'MDD':'Maximum Drawdown',
               'NHR':'Normalized Hit Ratio',
               'OTS':'Optimal trade size'}
    
    def __init__(self,data,short_window = 5, long_window = 40,
                 moving_average = "Simple", data_name = None, start = None,end = None ):

        """
         Doc string of the class. We define what class is about here
        """
        self.data=data #the dataframe
        self.data['yr'] = self.data['Date'].dt.year
        self.moving_average = moving_average
        if data_name is None:#the name that will appear on plots
            self.data_name = moving_average
        else:
            self.data_name=data_name
        self.short_window = short_window
        self.long_window = long_window
        self.n_days = (self.data.Date.iloc[-1] - self.data.Date.iloc[0])
        self.start=start #the beginning date of the sample period
        self.end=end #the ending date of the sample period

    def generate_signals(self, charts=True, burn=False):
        """
        This is an instance method. Only works on an object.
        """
        if self.long_window <= self.short_window: return

        if self.moving_average == "Simple":
            self.data["SMA"] = self.data.Close.rolling(self.short_window).mean()
            self.data["LMA"] = self.data.Close.rolling(self.long_window).mean()
        elif self.moving_average == "exponential":
            self.data["SMA"] = self.data.Close.ewm(span = self.short_window, adjust=True).mean()
            self.data["LMA"] = self.data.Close.ewm(span = self.long_window, adjust=True).mean()
        else:
            raise Exception("Not a valid type")

        self.data["_lag1_SMA"] = self.data.SMA.shift(1)
        self.data["_lag1_LMA"] = self.data.LMA.shift(1)

        ## creating signal    
        buy_mask = (self.data.SMA > self.data.LMA) & (self.data._lag1_SMA < self.data._lag1_LMA)
        sell_mask = (self.data.SMA < self.data.LMA) & (self.data._lag1_SMA > self.data._lag1_LMA)

        self.data['signal'] = np.nan
        self.data.loc[buy_mask,'signal'] = +1
        self.data.loc[sell_mask,'signal'] = -1
        if burn:
            burn_period = 2*self.long_window
            self.data.loc[:burn_period,"signal"] = np.nan
        self.data.signal = self.data.signal.fillna(method="ffill")

        mask = (self.data.signal != self.data.signal.shift(1)) & (self.data.signal.notnull())
        self.data['trade_num'] = np.where(mask,1,0).cumsum()

        ## display chart
        if charts:
            plt.plot(self.data['Date'],self.data['SMA'],color='black', label=f'SMA ={self.short_window}')
            plt.plot(self.data['Date'],self.data['LMA'],color='blue', label=f'LMA ={self.long_window}')
            plt.title('%s Strategy Backtest'%(self.data_name))
            plt.legend(loc=0)
            d_color = {}
            d_color[1] = '#90ee90'  ## light green
            d_color[-1] = "#ffcccb" ## light red

            j = 0
            for i in range(1,self.data.shape[0]):
                if np.isnan(self.data.signal[i-1]):
                    j=i
                elif (self.data.signal[i-1] == self.data.signal[i]) and (i< (self.data.shape[0]-1)):
                    continue
                else:
                    plt.axvspan(self.data['Date'][j], self.data['Date'][i], 
                               alpha=0.5, color=d_color[self.data.signal[i-1]], label="interval")
                    j = i
            plt.show()
        
    def signal_performance(self, allocation):
        """
        Another instance method
        """
        if self.long_window <= self.short_window: return
        self.allocation=allocation

        #creating returns and portfolio value series
        self.data['Return']=np.log(self.data['Close']/self.data['Close'].shift(1))
        self.data['S_Return']=self.data['signal'].shift(1)*self.data['Return']
        self.data['Market_Return']=self.data['Return'].expanding().sum()
        self.data['Strategy_Return']=self.data['S_Return'].expanding().sum()
        self.data['Portfolio Value']=((self.data['Strategy_Return']+1)*self.allocation)
        self.data['Wins']=np.where(self.data['S_Return'] > 0,1,0)
        self.data['Losses']=np.where(self.data['S_Return']<0,1,0)

        ## Daywise Performance
        d_perform = {}
        d_perform['TotalWins']=self.data['Wins'].sum()
        d_perform['TotalLosses']=self.data['Losses'].sum()
        d_perform['TotalTrades']=d_perform['TotalWins']+d_perform['TotalLosses']
        d_perform['HitRatio']=round(d_perform['TotalWins']/d_perform['TotalTrades'],2)
        d_perform['SharpeRatio'] = self.data["S_Return"].mean() / self.data["S_Return"].std() * (252**.5)        
        d_perform['CAGR'] = (1+self.data['Strategy_Return']).iloc[-1]**(365.25/self.n_days.days) -1
        d_perform['MaxDrawdown']=(1.0-self.data['Portfolio Value']/self.data['Portfolio Value'].cummax()).max()
        self.daywise_performance = pd.Series(d_perform)

        ## Tradewise performance
        _df = self.data.groupby(["signal","trade_num"]).S_Return.sum().reset_index()
        _df['Wins']=np.where(_df['S_Return'] > 0,1,0)
        _df['Losses']=np.where(_df['S_Return']<0,1,0)
        d_tp = {}
        d_tp.update(_df[["Wins","Losses"]].sum().rename({'Wins':'TotalWins','Losses':'TotalLosses'}).to_dict())
        d_tp['TotalTrades'] = d_tp["TotalWins"] + d_tp["TotalLosses"]
        d_tp['HitRatio'] =  np.round(d_tp["TotalWins"] / d_tp['TotalTrades'],4)
        d_tp['AvgWinRet'] = np.round(_df[_df.Wins==1].S_Return.mean(),4)
        d_tp['AvgLossRet'] = np.round(_df[_df.Losses==1].S_Return.mean(),4)
        d_tp['WinByLossRet'] = np.round(abs(d_tp['AvgWinRet']/d_tp['AvgLossRet']),2)
        d_tp['RetVar'] = np.round(_df.S_Return.std(),4)
        _sum = _df.groupby("Wins").S_Return.sum()
        d_tp['NormHitRatio'] = np.round(_sum[1]/_sum.abs().sum(),4)
        d_tp['OptimalTradeSize'] = self.kelly(p = d_tp['HitRatio'], b = d_tp['WinByLossRet'])
        self.tradewise_performance = pd.Series(d_tp)

    @staticmethod
    def kelly(p,b):
        """
        Static method: No object or class related arguments
        p: win prob, b: net odds received on wager, output(f*) = p - (1-p)/b

        Spreadsheet example
            from sympy import symbols, solve, diff
            x = symbols('x')
            y = (1+3.3*x)**37 *(1-x)**63
            solve(diff(y, x), x)[1]
        Shortcut
            .37 - 0.63/3.3
        """
        return np.round(p - (1-p)/b,4)

    def plot_performance(self, allocation=1):
        #intializing a variable for initial allocation
        #to be used to create equity curve
        self.signal_performance(allocation)
        
        #yearly performance
        self.yearly_performance()
        
        #Plotting the Performance of the strategy
        plt.plot(self.data['Date'],self.data['Market_Return'],color='black', label='Market Returns')
        plt.plot(self.data['Date'],self.data['Strategy_Return'],color='blue', label= 'Strategy Returns')
        plt.title('%s Strategy Backtest'%(self.data_name))
        plt.legend(loc=0)
        plt.tight_layout()
        plt.show()

        plt.plot(self.data['Date'],self.data['Portfolio Value'], color='blue')
        plt.title('%s Portfolio Value'%(self.data_name))
        plt.show()
        
    def yearly_performance(self):
        """
        Instance method
        Adds an instance attribute: yearly_df
        """
        _yearly_df = self.data.groupby(['yr','signal']).S_Return.sum().unstack()
        _yearly_df.rename(columns={-1.0:'Sell',1.0:'Buy'}, inplace=True)
        _yearly_df['Return'] = _yearly_df.sum(1)

        # yearly_df
        self.yearly_df = _yearly_df.style.bar(color=["#ffcccb",'#90ee90'], align = 'zero').format({
            'Sell': '{:,.2%}'.format,'Buy': '{:,.2%}'.format,'Return': '{:,.2%}'.format})
    
    def update_metrics(self):
        """
        Called from the SMA_LMA_matrix class method
        """
        d_field = {}
        if self.long_window > self.short_window:
            d_field['Sharpe'] = self.daywise_performance.SharpeRatio
            d_field['CAGR'] = self.daywise_performance.CAGR
            d_field['MDD'] = self.daywise_performance.MaxDrawdown
            d_field['NHR'] = self.tradewise_performance.NormHitRatio
            d_field['OTS'] = self.tradewise_performance.OptimalTradeSize
            
        return d_field
    
    @classmethod
    def SMA_LMA_matrix(cls,data, LMA_range, SMA_range, metrics, moving_average = "Simple", optimal_sol = True):
        """
        This is a class method. First argument is a class.
        """
        c_green = sns.light_palette("green", as_cmap=True)
        c_red = sns.light_palette("red", as_cmap=True)
        
        d_mats = {m:[] for m in metrics}
        
        for l in LMA_range:
            d_row = {m:[] for m in metrics}
            for s in SMA_range:
                obj = cls(data, s, l, moving_average) ## object being created from the class
                obj.generate_signals(charts=False)
                obj.signal_performance(100)
                d_field = obj.update_metrics()
                for m in metrics: d_row[m].append(d_field.get(m,np.nan))
            for m in metrics: d_mats[m].append(d_row[m])
                
        d_df = {m:pd.DataFrame(d_mats[m], index=LMA_range, columns=SMA_range) for m in metrics}

        def optimal(_df):
            """ 
            This is a function inside a function.
            We could have created it outside the class if needed, but that would made it harder to relate. 
            """
            _df = _df.stack().rank()
            _df = (_df - _df.mean())/_df.std()
            return _df.unstack()

        if optimal_sol:
            d_df['Signal'] = 0
            if 'Sharpe' in metrics: d_df['Signal'] += 2*optimal(d_df['Sharpe'])
            if 'NHR' in metrics: d_df['Signal'] += optimal(d_df['NHR'])
            if 'CAGR' in metrics: d_df['Signal'] += optimal(d_df['CAGR'])
            if 'MDD' in metrics: d_df['Signal'] -= 2*optimal(d_df['MDD'])
            l_i,s_i = np.unravel_index(np.argmax(d_df['Signal'].values), d_df['Signal'].shape)
            print(f"Most optimal cross-over pair is SMA:{SMA_range[s_i]}, LMA:{LMA_range[l_i]}")
            metrics.insert(0,'Signal')

        for m in metrics:
            display(HTML(d_df[m].style.background_gradient(axis=None, cmap=
                c_red if m=="MDD" else c_green).format(
                ("{:,.2}" if m in ["Sharpe","Signal"] else "{:.2%}")).set_caption(m).render()))
            
        return d_df

# %%
close_df = pd.read_csv("class_data.csv", parse_dates = [0])

# %%
close_df.head()
# Out:
#         Date   Close
# 0 2000-01-03  1592.2
# 1 2000-01-04  1638.7
# 2 2000-01-05  1595.8
# 3 2000-01-06  1617.6
# 4 2000-01-07  1613.3

# %%
close_df.shape
# Out:
# (4235, 2)

# %%
close_df.head()
# Out:
#         Date   Close
# 0 2000-01-03  1592.2
# 1 2000-01-04  1638.7
# 2 2000-01-05  1595.8
# 3 2000-01-06  1617.6
# 4 2000-01-07  1613.3

# %%
close_df.tail()
# Out:
#            Date    Close
# 4230 2016-12-26  7908.25
# 4231 2016-12-27  8032.85
# 4232 2016-12-28  8034.85
# 4233 2016-12-29  8103.60
# 4234 2016-12-30  8185.80

# %%
# close_df.Close.ewm(span = 20, adjust=False, min_periods=20).mean()

# %%
CROSSOVER.metrics
# Out:
# {'Sharpe': 'Sharpe Ratio',
#  'CAGR': 'Compound Average Growth Rate',
#  'MDD': 'Maximum Drawdown',
#  'NHR': 'Normalized Hit Ratio',
#  'OTS': 'Optimal trade size'}

# %%
CROSSOVER.moving_average
# Out:
# ('Simple', 'exponential')

# %%
## Possible values for metrics : 'Sharpe','CAGR','MDD','NHR','OTS'
_ = CROSSOVER.SMA_LMA_matrix(close_df, SMA_range=range(9,44,5), LMA_range=range(40,120,5),
                             metrics = ['CAGR','MDD','Sharpe'], moving_average='Simple')
# Out:
# Most optimal cross-over pair is SMA:24, LMA:90
# <style  type="text/css" >
# #T_008d9_row0_col0{
#             background-color:  #1e8f1e;
#             color:  #000000;
#         }#T_008d9_row0_col1,#T_008d9_row9_col6{
#             background-color:  #249224;
#             color:  #000000;
#         }#T_008d9_row0_col2{
#             background-color:  #a4d0a4;
#             color:  #000000;
#         }#T_008d9_row0_col3{
#             background-color:  #e3efe3;
#             color:  #000000;
#         }#T_008d9_row0_col4{
#             background-color:  #dfeddf;
#             color:  #000000;
#         }#T_008d9_row0_col5{
#             background-color:  #cfe5cf;
#             color:  #000000;
#         }#T_008d9_row0_col6,#T_008d9_row1_col6,#T_008d9_row12_col2{
#             background-color:  #9bcc9b;
#             color:  #000000;
#         }#T_008d9_row1_col0{
#             background-color:  #188c18;
#             color:  #000000;
#         }#T_008d9_row1_col1{
#             background-color:  #8dc58d;
#             color:  #000000;
#         }#T_008d9_row1_col2{
#             background-color:  #b3d8b3;
#             color:  #000000;
#         }#T_008d9_row1_col3{
#             background-color:  #deedde;
#             color:  #000000;
#         }#T_008d9_row1_col4{
#             background-color:  #d9ead9;
#             color:  #000000;
#         }#T_008d9_row1_col5{
#             background-color:  #d0e6d0;
#             color:  #000000;
#         }#T_008d9_row2_col0,#T_008d9_row14_col1,#T_008d9_row14_col4{
#             background-color:  #54a954;
#             color:  #000000;
#         }#T_008d9_row2_col1,#T_008d9_row6_col5{
#             background-color:  #8bc48b;
#             color:  #000000;
#         }#T_008d9_row2_col2{
#             background-color:  #c9e2c8;
#             color:  #000000;
#         }#T_008d9_row2_col3{
#             background-color:  #b1d7b1;
#             color:  #000000;
#         }#T_008d9_row2_col4{
#             background-color:  #cae3ca;
#             color:  #000000;
#         }#T_008d9_row2_col5{
#             background-color:  #b8dab8;
#             color:  #000000;
#         }#T_008d9_row2_col6{
#             background-color:  #d6e9d6;
#             color:  #000000;
#         }#T_008d9_row3_col0,#T_008d9_row11_col3{
#             background-color:  #50a750;
#             color:  #000000;
#         }#T_008d9_row3_col1,#T_008d9_row11_col1,#T_008d9_row15_col4{
#             background-color:  #84c084;
#             color:  #000000;
#         }#T_008d9_row3_col2{
#             background-color:  #d7e9d7;
#             color:  #000000;
#         }#T_008d9_row3_col3,#T_008d9_row3_col4{
#             background-color:  #8fc68f;
#             color:  #000000;
#         }#T_008d9_row3_col5{
#             background-color:  #c1dfc1;
#             color:  #000000;
#         }#T_008d9_row3_col6{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_008d9_row4_col0{
#             background-color:  #2e972e;
#             color:  #000000;
#         }#T_008d9_row4_col1,#T_008d9_row15_col3{
#             background-color:  #a2cfa2;
#             color:  #000000;
#         }#T_008d9_row4_col2{
#             background-color:  #a6d1a6;
#             color:  #000000;
#         }#T_008d9_row4_col3{
#             background-color:  #81bf81;
#             color:  #000000;
#         }#T_008d9_row4_col4{
#             background-color:  #87c287;
#             color:  #000000;
#         }#T_008d9_row4_col5{
#             background-color:  #b9dbb9;
#             color:  #000000;
#         }#T_008d9_row4_col6{
#             background-color:  #e2efe2;
#             color:  #000000;
#         }#T_008d9_row5_col0{
#             background-color:  #2a952a;
#             color:  #000000;
#         }#T_008d9_row5_col1{
#             background-color:  #90c790;
#             color:  #000000;
#         }#T_008d9_row5_col2{
#             background-color:  #63b163;
#             color:  #000000;
#         }#T_008d9_row5_col3,#T_008d9_row8_col3{
#             background-color:  #5bad5b;
#             color:  #000000;
#         }#T_008d9_row5_col4{
#             background-color:  #c3e0c3;
#             color:  #000000;
#         }#T_008d9_row5_col5{
#             background-color:  #9dcd9d;
#             color:  #000000;
#         }#T_008d9_row5_col6{
#             background-color:  #d1e6d1;
#             color:  #000000;
#         }#T_008d9_row6_col0{
#             background-color:  #299429;
#             color:  #000000;
#         }#T_008d9_row6_col1,#T_008d9_row11_col0{
#             background-color:  #6ab46a;
#             color:  #000000;
#         }#T_008d9_row6_col2,#T_008d9_row14_col2{
#             background-color:  #73b873;
#             color:  #000000;
#         }#T_008d9_row6_col3,#T_008d9_row11_col2{
#             background-color:  #71b771;
#             color:  #000000;
#         }#T_008d9_row6_col4,#T_008d9_row9_col2{
#             background-color:  #82c082;
#             color:  #000000;
#         }#T_008d9_row6_col6,#T_008d9_row13_col3{
#             background-color:  #a0cea0;
#             color:  #000000;
#         }#T_008d9_row7_col0{
#             background-color:  #1f8f1f;
#             color:  #000000;
#         }#T_008d9_row7_col1{
#             background-color:  #53a953;
#             color:  #000000;
#         }#T_008d9_row7_col2,#T_008d9_row15_col2{
#             background-color:  #62b062;
#             color:  #000000;
#         }#T_008d9_row7_col3{
#             background-color:  #52a852;
#             color:  #000000;
#         }#T_008d9_row7_col4{
#             background-color:  #47a347;
#             color:  #000000;
#         }#T_008d9_row7_col5{
#             background-color:  #61b061;
#             color:  #000000;
#         }#T_008d9_row7_col6,#T_008d9_row10_col1{
#             background-color:  #72b872;
#             color:  #000000;
#         }#T_008d9_row8_col0{
#             background-color:  #309730;
#             color:  #000000;
#         }#T_008d9_row8_col1{
#             background-color:  #84c184;
#             color:  #000000;
#         }#T_008d9_row8_col2{
#             background-color:  #40a040;
#             color:  #000000;
#         }#T_008d9_row8_col4,#T_008d9_row11_col5{
#             background-color:  #118911;
#             color:  #f1f1f1;
#         }#T_008d9_row8_col5,#T_008d9_row13_col1{
#             background-color:  #5dae5d;
#             color:  #000000;
#         }#T_008d9_row8_col6,#T_008d9_row12_col4{
#             background-color:  #4ea64e;
#             color:  #000000;
#         }#T_008d9_row9_col0{
#             background-color:  #2d962d;
#             color:  #000000;
#         }#T_008d9_row9_col1{
#             background-color:  #b7dab7;
#             color:  #000000;
#         }#T_008d9_row9_col3{
#             background-color:  #1a8d1a;
#             color:  #000000;
#         }#T_008d9_row9_col4,#T_008d9_row10_col6{
#             background-color:  #128912;
#             color:  #f1f1f1;
#         }#T_008d9_row9_col5{
#             background-color:  #399c39;
#             color:  #000000;
#         }#T_008d9_row10_col0{
#             background-color:  #3a9c3a;
#             color:  #000000;
#         }#T_008d9_row10_col2,#T_008d9_row14_col3{
#             background-color:  #86c286;
#             color:  #000000;
#         }#T_008d9_row10_col3{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_008d9_row10_col4{
#             background-color:  #359a35;
#             color:  #000000;
#         }#T_008d9_row10_col5{
#             background-color:  #148a14;
#             color:  #000000;
#         }#T_008d9_row11_col4{
#             background-color:  #389b38;
#             color:  #000000;
#         }#T_008d9_row11_col6{
#             background-color:  #0d860d;
#             color:  #f1f1f1;
#         }#T_008d9_row12_col0{
#             background-color:  #8ec58e;
#             color:  #000000;
#         }#T_008d9_row12_col1{
#             background-color:  #75b975;
#             color:  #000000;
#         }#T_008d9_row12_col3{
#             background-color:  #6db66d;
#             color:  #000000;
#         }#T_008d9_row12_col5{
#             background-color:  #0b850b;
#             color:  #f1f1f1;
#         }#T_008d9_row12_col6{
#             background-color:  #158a15;
#             color:  #000000;
#         }#T_008d9_row13_col0{
#             backgro
# <style  type="text/css" >
# #T_30271_row0_col0,#T_30271_row1_col0{
#             background-color:  #068306;
#             color:  #f1f1f1;
#         }#T_30271_row0_col1{
#             background-color:  #148a14;
#             color:  #000000;
#         }#T_30271_row0_col2,#T_30271_row2_col3{
#             background-color:  #7bbc7b;
#             color:  #000000;
#         }#T_30271_row0_col3{
#             background-color:  #e0eedf;
#             color:  #000000;
#         }#T_30271_row0_col4{
#             background-color:  #d3e7d3;
#             color:  #000000;
#         }#T_30271_row0_col5,#T_30271_row6_col6{
#             background-color:  #7cbd7c;
#             color:  #000000;
#         }#T_30271_row0_col6{
#             background-color:  #4ba54b;
#             color:  #000000;
#         }#T_30271_row1_col1,#T_30271_row6_col4{
#             background-color:  #56aa56;
#             color:  #000000;
#         }#T_30271_row1_col2{
#             background-color:  #89c389;
#             color:  #000000;
#         }#T_30271_row1_col3{
#             background-color:  #c5e0c5;
#             color:  #000000;
#         }#T_30271_row1_col4{
#             background-color:  #beddbe;
#             color:  #000000;
#         }#T_30271_row1_col5{
#             background-color:  #afd6af;
#             color:  #000000;
#         }#T_30271_row1_col6,#T_30271_row8_col3{
#             background-color:  #4aa44a;
#             color:  #000000;
#         }#T_30271_row2_col0{
#             background-color:  #209020;
#             color:  #000000;
#         }#T_30271_row2_col1,#T_30271_row15_col4{
#             background-color:  #5dae5d;
#             color:  #000000;
#         }#T_30271_row2_col2{
#             background-color:  #83c083;
#             color:  #000000;
#         }#T_30271_row2_col4{
#             background-color:  #a9d3a9;
#             color:  #000000;
#         }#T_30271_row2_col5{
#             background-color:  #7dbd7d;
#             color:  #000000;
#         }#T_30271_row2_col6,#T_30271_row5_col6{
#             background-color:  #b3d8b3;
#             color:  #000000;
#         }#T_30271_row3_col0{
#             background-color:  #2c962c;
#             color:  #000000;
#         }#T_30271_row3_col1{
#             background-color:  #4ea64e;
#             color:  #000000;
#         }#T_30271_row3_col2{
#             background-color:  #82c082;
#             color:  #000000;
#         }#T_30271_row3_col3{
#             background-color:  #61b061;
#             color:  #000000;
#         }#T_30271_row3_col4{
#             background-color:  #4da64d;
#             color:  #000000;
#         }#T_30271_row3_col5{
#             background-color:  #95c995;
#             color:  #000000;
#         }#T_30271_row3_col6{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_30271_row4_col0,#T_30271_row9_col3{
#             background-color:  #269226;
#             color:  #000000;
#         }#T_30271_row4_col1{
#             background-color:  #6db56d;
#             color:  #000000;
#         }#T_30271_row4_col2{
#             background-color:  #6eb66e;
#             color:  #000000;
#         }#T_30271_row4_col3{
#             background-color:  #6ab46a;
#             color:  #000000;
#         }#T_30271_row4_col4{
#             background-color:  #6bb46b;
#             color:  #000000;
#         }#T_30271_row4_col5{
#             background-color:  #86c286;
#             color:  #000000;
#         }#T_30271_row4_col6{
#             background-color:  #cce4cc;
#             color:  #000000;
#         }#T_30271_row5_col0,#T_30271_row6_col0,#T_30271_row11_col0,#T_30271_row13_col1{
#             background-color:  #249224;
#             color:  #000000;
#         }#T_30271_row5_col1,#T_30271_row7_col5{
#             background-color:  #4ca54c;
#             color:  #000000;
#         }#T_30271_row5_col2{
#             background-color:  #3e9e3e;
#             color:  #000000;
#         }#T_30271_row5_col3{
#             background-color:  #49a449;
#             color:  #000000;
#         }#T_30271_row5_col4{
#             background-color:  #acd4ac;
#             color:  #000000;
#         }#T_30271_row5_col5{
#             background-color:  #6fb76f;
#             color:  #000000;
#         }#T_30271_row6_col1{
#             background-color:  #3d9e3d;
#             color:  #000000;
#         }#T_30271_row6_col2,#T_30271_row9_col2,#T_30271_row14_col2{
#             background-color:  #3f9f3f;
#             color:  #000000;
#         }#T_30271_row6_col3{
#             background-color:  #52a852;
#             color:  #000000;
#         }#T_30271_row6_col5{
#             background-color:  #76ba76;
#             color:  #000000;
#         }#T_30271_row7_col0{
#             background-color:  #118811;
#             color:  #f1f1f1;
#         }#T_30271_row7_col1,#T_30271_row11_col3{
#             background-color:  #2e972e;
#             color:  #000000;
#         }#T_30271_row7_col2,#T_30271_row12_col3{
#             background-color:  #40a040;
#             color:  #000000;
#         }#T_30271_row7_col3,#T_30271_row7_col4{
#             background-color:  #43a143;
#             color:  #000000;
#         }#T_30271_row7_col6{
#             background-color:  #59ac59;
#             color:  #000000;
#         }#T_30271_row8_col0{
#             background-color:  #118911;
#             color:  #f1f1f1;
#         }#T_30271_row8_col1{
#             background-color:  #389b38;
#             color:  #000000;
#         }#T_30271_row8_col2,#T_30271_row10_col1,#T_30271_row11_col4{
#             background-color:  #299429;
#             color:  #000000;
#         }#T_30271_row8_col4{
#             background-color:  #229122;
#             color:  #000000;
#         }#T_30271_row8_col5,#T_30271_row12_col2{
#             background-color:  #45a245;
#             color:  #000000;
#         }#T_30271_row8_col6,#T_30271_row14_col4{
#             background-color:  #4ba54a;
#             color:  #000000;
#         }#T_30271_row9_col0{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_30271_row9_col1{
#             background-color:  #51a851;
#             color:  #000000;
#         }#T_30271_row9_col4,#T_30271_row10_col5{
#             background-color:  #1d8e1d;
#             color:  #000000;
#         }#T_30271_row9_col5,#T_30271_row15_col6{
#             background-color:  #349934;
#             color:  #000000;
#         }#T_30271_row9_col6{
#             background-color:  #279327;
#             color:  #000000;
#         }#T_30271_row10_col0{
#             background-color:  #018001;
#             color:  #f1f1f1;
#         }#T_30271_row10_col2{
#             background-color:  #3b9d3b;
#             color:  #000000;
#         }#T_30271_row10_col3{
#             background-color:  #138913;
#             color:  #f1f1f1;
#         }#T_30271_row10_col4{
#             background-color:  #2a952a;
#             color:  #000000;
#         }#T_30271_row10_col6,#T_30271_row15_col1{
#             background-color:  #1f8f1f;
#             color:  #000000;
#         }#T_30271_row11_col1,#T_30271_row13_col6{
#             background-color:  #2b952b;
#             color:  #000000;
#         }#T_30271_row11_col2{
#             background-color:  #2d962d;
#             color:  #000000;
#         }#T_30271_row11_col5,#T_30271_row15_col0{
#             background-color:  #1e8f1e;
#             color:  #000000;
#         }#T_30271_row11_col6{
#             background-color:  #178b17;
#             color:  #000000;
#         }#T_30271_row12_col0,#T_30271_row13_col4{
#             background-color:  #309730;
#             color:  #000000;
#         }#T_30271_row12_col1{
#             background-color:  #289328;
#             color:  #000000;
#         }#T_30271_row12_col4{
#             background-color:  #3a9c3a;
#             color:  #000000;
#         }#T_30271_row12_col5,#T_30271_row12_col6,#T_30271_row14_col5{
#             background-color:  #1a8d1a;
#             color:  #000000;
#         }#T_30271_row13_col0,#T_30271_row15_col5{
#             background-color:  #379b37;
#             color:  #000000;
#         }#T_30271_row13_col2{
#             background-color:  #53a953;
#             color:  #000000;
#         }#T_30271_row13_col3{
#             background-color:  #5eae5e;
#             color:  #000000;
#         }#T_30271_row13_col5
# <style  type="text/css" >
# #T_82df3_row0_col0,#T_82df3_row15_col4{
#             background-color:  #f6adad;
#             color:  #000000;
#         }#T_82df3_row0_col1{
#             background-color:  #f6b1b1;
#             color:  #000000;
#         }#T_82df3_row0_col2,#T_82df3_row8_col0{
#             background-color:  #f79999;
#             color:  #000000;
#         }#T_82df3_row0_col3,#T_82df3_row14_col0{
#             background-color:  #fc3e3e;
#             color:  #f1f1f1;
#         }#T_82df3_row0_col4{
#             background-color:  #fc4343;
#             color:  #000000;
#         }#T_82df3_row0_col5{
#             background-color:  #fc3939;
#             color:  #f1f1f1;
#         }#T_82df3_row0_col6{
#             background-color:  #f96f6f;
#             color:  #000000;
#         }#T_82df3_row1_col0,#T_82df3_row15_col2{
#             background-color:  #f6b8b8;
#             color:  #000000;
#         }#T_82df3_row1_col1{
#             background-color:  #f79b9b;
#             color:  #000000;
#         }#T_82df3_row1_col2,#T_82df3_row4_col1{
#             background-color:  #f89191;
#             color:  #000000;
#         }#T_82df3_row1_col3,#T_82df3_row12_col1{
#             background-color:  #fc4040;
#             color:  #f1f1f1;
#         }#T_82df3_row1_col4{
#             background-color:  #fb4b4b;
#             color:  #000000;
#         }#T_82df3_row1_col5{
#             background-color:  #fa5b5b;
#             color:  #000000;
#         }#T_82df3_row1_col6{
#             background-color:  #fa6363;
#             color:  #000000;
#         }#T_82df3_row2_col0,#T_82df3_row2_col3{
#             background-color:  #f88686;
#             color:  #000000;
#         }#T_82df3_row2_col1,#T_82df3_row7_col1{
#             background-color:  #f7a5a5;
#             color:  #000000;
#         }#T_82df3_row2_col2{
#             background-color:  #fb5252;
#             color:  #000000;
#         }#T_82df3_row2_col4{
#             background-color:  #fa6262;
#             color:  #000000;
#         }#T_82df3_row2_col5,#T_82df3_row5_col4{
#             background-color:  #f97979;
#             color:  #000000;
#         }#T_82df3_row2_col6{
#             background-color:  #fb4e4e;
#             color:  #000000;
#         }#T_82df3_row3_col0{
#             background-color:  #f7a3a3;
#             color:  #000000;
#         }#T_82df3_row3_col1{
#             background-color:  #f79d9d;
#             color:  #000000;
#         }#T_82df3_row3_col2{
#             background-color:  #fd2c2c;
#             color:  #f1f1f1;
#         }#T_82df3_row3_col3{
#             background-color:  #f7a2a2;
#             color:  #000000;
#         }#T_82df3_row3_col4{
#             background-color:  #f89494;
#             color:  #000000;
#         }#T_82df3_row3_col5{
#             background-color:  #f97474;
#             color:  #000000;
#         }#T_82df3_row3_col6{
#             background-color:  #fd2f2f;
#             color:  #f1f1f1;
#         }#T_82df3_row4_col0{
#             background-color:  #f5cdcd;
#             color:  #000000;
#         }#T_82df3_row4_col2{
#             background-color:  #f88f8f;
#             color:  #000000;
#         }#T_82df3_row4_col3,#T_82df3_row11_col4{
#             background-color:  #f5c4c4;
#             color:  #000000;
#         }#T_82df3_row4_col4,#T_82df3_row6_col5{
#             background-color:  #f6b4b4;
#             color:  #000000;
#         }#T_82df3_row4_col5{
#             background-color:  #f88888;
#             color:  #000000;
#         }#T_82df3_row4_col6{
#             background-color:  #fc3a3a;
#             color:  #f1f1f1;
#         }#T_82df3_row5_col0{
#             background-color:  #f5cccc;
#             color:  #000000;
#         }#T_82df3_row5_col1{
#             background-color:  #f88a8a;
#             color:  #000000;
#         }#T_82df3_row5_col2{
#             background-color:  #f6a9a9;
#             color:  #000000;
#         }#T_82df3_row5_col3,#T_82df3_row10_col4,#T_82df3_row12_col6{
#             background-color:  #f4cfcf;
#             color:  #000000;
#         }#T_82df3_row5_col5,#T_82df3_row6_col1,#T_82df3_row6_col6{
#             background-color:  #f79a9a;
#             color:  #000000;
#         }#T_82df3_row5_col6{
#             background-color:  #fa5c5c;
#             color:  #000000;
#         }#T_82df3_row6_col0{
#             background-color:  #f5c7c7;
#             color:  #000000;
#         }#T_82df3_row6_col2,#T_82df3_row13_col6{
#             background-color:  #f79898;
#             color:  #000000;
#         }#T_82df3_row6_col3{
#             background-color:  #f5c5c5;
#             color:  #000000;
#         }#T_82df3_row6_col4{
#             background-color:  #f6aaaa;
#             color:  #000000;
#         }#T_82df3_row7_col0{
#             background-color:  #f6afaf;
#             color:  #000000;
#         }#T_82df3_row7_col2{
#             background-color:  #f6b2b2;
#             color:  #000000;
#         }#T_82df3_row7_col3{
#             background-color:  #f4d7d7;
#             color:  #000000;
#         }#T_82df3_row7_col4{
#             background-color:  #f3e5e5;
#             color:  #000000;
#         }#T_82df3_row7_col5{
#             background-color:  #f4d4d4;
#             color:  #000000;
#         }#T_82df3_row7_col6{
#             background-color:  #f5cbcb;
#             color:  #000000;
#         }#T_82df3_row8_col1{
#             background-color:  #fa5d5d;
#             color:  #000000;
#         }#T_82df3_row8_col2{
#             background-color:  #f6b3b3;
#             color:  #000000;
#         }#T_82df3_row8_col3{
#             background-color:  #f4d6d6;
#             color:  #000000;
#         }#T_82df3_row8_col4{
#             background-color:  #f3e7e7;
#             color:  #000000;
#         }#T_82df3_row8_col5{
#             background-color:  #f5caca;
#             color:  #000000;
#         }#T_82df3_row8_col6{
#             background-color:  #f3f0f0;
#             color:  #000000;
#         }#T_82df3_row9_col0,#T_82df3_row15_col5{
#             background-color:  #f79595;
#             color:  #000000;
#         }#T_82df3_row9_col1{
#             background-color:  #fd3131;
#             color:  #f1f1f1;
#         }#T_82df3_row9_col2{
#             background-color:  #f88181;
#             color:  #000000;
#         }#T_82df3_row9_col3,#T_82df3_row10_col3{
#             background-color:  #f3ebeb;
#             color:  #000000;
#         }#T_82df3_row9_col4,#T_82df3_row10_col5,#T_82df3_row11_col6,#T_82df3_row13_col5{
#             background-color:  #f4d8d8;
#             color:  #000000;
#         }#T_82df3_row9_col5{
#             background-color:  #f4dcdc;
#             color:  #000000;
#         }#T_82df3_row9_col6,#T_82df3_row14_col4{
#             background-color:  #f4d9d9;
#             color:  #000000;
#         }#T_82df3_row10_col0{
#             background-color:  #f97c7c;
#             color:  #000000;
#         }#T_82df3_row10_col1,#T_82df3_row12_col2{
#             background-color:  #fb5050;
#             color:  #000000;
#         }#T_82df3_row10_col2{
#             background-color:  #fa5e5e;
#             color:  #000000;
#         }#T_82df3_row10_col6,#T_82df3_row12_col5{
#             background-color:  #f4e1e1;
#             color:  #000000;
#         }#T_82df3_row11_col0{
#             background-color:  #fb4a4a;
#             color:  #000000;
#         }#T_82df3_row11_col1{
#             background-color:  #fc3333;
#             color:  #f1f1f1;
#         }#T_82df3_row11_col2{
#             background-color:  #f96e6e;
#             color:  #000000;
#         }#T_82df3_row11_col3{
#             background-color:  #f7a8a7;
#             color:  #000000;
#         }#T_82df3_row11_col5{
#             background-color:  #f4dddd;
#             color:  #000000;
#         }#T_82df3_row12_col0{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_82df3_row12_col3{
#             background-color:  #f79f9f;
#             color:  #000000;
#         }#T_82df3_row12_col4{
#             background-color:  #f5c8c8;
#             color:  #000000;
#         }#T_82df3_row13_col0{
#             background-color:  #fc3434;
#             color:  #f1f1f1;
#         }#T_82df3_row13_col1{
#             background-color:  #fa6969;
#             color:  #000000;
#         }#T_82df3_row13_col2{
#             backgro
# <style  type="text/css" >
# #T_e2c88_row0_col0{
#             background-color:  #108810;
#             color:  #f1f1f1;
#         }#T_e2c88_row0_col1{
#             background-color:  #279327;
#             color:  #000000;
#         }#T_e2c88_row0_col2,#T_e2c88_row0_col5{
#             background-color:  #9fce9f;
#             color:  #000000;
#         }#T_e2c88_row0_col3{
#             background-color:  #e5f0e5;
#             color:  #000000;
#         }#T_e2c88_row0_col4{
#             background-color:  #deedde;
#             color:  #000000;
#         }#T_e2c88_row0_col6{
#             background-color:  #6db66d;
#             color:  #000000;
#         }#T_e2c88_row1_col0{
#             background-color:  #118911;
#             color:  #f1f1f1;
#         }#T_e2c88_row1_col1,#T_e2c88_row7_col6{
#             background-color:  #7abc7a;
#             color:  #000000;
#         }#T_e2c88_row1_col2{
#             background-color:  #aad3aa;
#             color:  #000000;
#         }#T_e2c88_row1_col3{
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_e2c88_row1_col4{
#             background-color:  #d1e6d1;
#             color:  #000000;
#         }#T_e2c88_row1_col5{
#             background-color:  #c8e2c8;
#             color:  #000000;
#         }#T_e2c88_row1_col6,#T_e2c88_row5_col1,#T_e2c88_row7_col5{
#             background-color:  #6cb56c;
#             color:  #000000;
#         }#T_e2c88_row2_col0,#T_e2c88_row5_col0,#T_e2c88_row11_col0,#T_e2c88_row14_col1{
#             background-color:  #389b38;
#             color:  #000000;
#         }#T_e2c88_row2_col1{
#             background-color:  #82c082;
#             color:  #000000;
#         }#T_e2c88_row2_col2{
#             background-color:  #a6d1a6;
#             color:  #000000;
#         }#T_e2c88_row2_col3{
#             background-color:  #9ece9e;
#             color:  #000000;
#         }#T_e2c88_row2_col4{
#             background-color:  #c3e0c3;
#             color:  #000000;
#         }#T_e2c88_row2_col5{
#             background-color:  #a0cea0;
#             color:  #000000;
#         }#T_e2c88_row2_col6,#T_e2c88_row5_col6{
#             background-color:  #cae3ca;
#             color:  #000000;
#         }#T_e2c88_row3_col0{
#             background-color:  #43a143;
#             color:  #000000;
#         }#T_e2c88_row3_col1{
#             background-color:  #6eb66e;
#             color:  #000000;
#         }#T_e2c88_row3_col2{
#             background-color:  #a5d1a5;
#             color:  #000000;
#         }#T_e2c88_row3_col3{
#             background-color:  #86c286;
#             color:  #000000;
#         }#T_e2c88_row3_col4{
#             background-color:  #70b770;
#             color:  #000000;
#         }#T_e2c88_row3_col5{
#             background-color:  #b4d8b4;
#             color:  #000000;
#         }#T_e2c88_row3_col6{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_e2c88_row4_col0{
#             background-color:  #3c9d3c;
#             color:  #000000;
#         }#T_e2c88_row4_col1,#T_e2c88_row4_col4{
#             background-color:  #8fc68f;
#             color:  #000000;
#         }#T_e2c88_row4_col2{
#             background-color:  #91c791;
#             color:  #000000;
#         }#T_e2c88_row4_col3{
#             background-color:  #8cc58c;
#             color:  #000000;
#         }#T_e2c88_row4_col5{
#             background-color:  #a8d2a8;
#             color:  #000000;
#         }#T_e2c88_row4_col6{
#             background-color:  #daebda;
#             color:  #000000;
#         }#T_e2c88_row5_col2,#T_e2c88_row6_col2,#T_e2c88_row9_col2{
#             background-color:  #5bad5b;
#             color:  #000000;
#         }#T_e2c88_row5_col3{
#             background-color:  #67b267;
#             color:  #000000;
#         }#T_e2c88_row5_col4{
#             background-color:  #c5e0c5;
#             color:  #000000;
#         }#T_e2c88_row5_col5{
#             background-color:  #93c893;
#             color:  #000000;
#         }#T_e2c88_row6_col0,#T_e2c88_row13_col1{
#             background-color:  #379b37;
#             color:  #000000;
#         }#T_e2c88_row6_col1{
#             background-color:  #59ac59;
#             color:  #000000;
#         }#T_e2c88_row6_col3{
#             background-color:  #72b872;
#             color:  #000000;
#         }#T_e2c88_row6_col4{
#             background-color:  #78bb78;
#             color:  #000000;
#         }#T_e2c88_row6_col5{
#             background-color:  #98ca98;
#             color:  #000000;
#         }#T_e2c88_row6_col6{
#             background-color:  #9dcd9d;
#             color:  #000000;
#         }#T_e2c88_row7_col0{
#             background-color:  #1c8e1c;
#             color:  #000000;
#         }#T_e2c88_row7_col1{
#             background-color:  #47a347;
#             color:  #000000;
#         }#T_e2c88_row7_col2{
#             background-color:  #5eae5e;
#             color:  #000000;
#         }#T_e2c88_row7_col3,#T_e2c88_row7_col4{
#             background-color:  #61af61;
#             color:  #000000;
#         }#T_e2c88_row8_col0{
#             background-color:  #1d8e1d;
#             color:  #000000;
#         }#T_e2c88_row8_col1{
#             background-color:  #54a954;
#             color:  #000000;
#         }#T_e2c88_row8_col2,#T_e2c88_row10_col1,#T_e2c88_row11_col4{
#             background-color:  #3f9f3f;
#             color:  #000000;
#         }#T_e2c88_row8_col3{
#             background-color:  #69b369;
#             color:  #000000;
#         }#T_e2c88_row8_col4{
#             background-color:  #349a34;
#             color:  #000000;
#         }#T_e2c88_row8_col5,#T_e2c88_row12_col2{
#             background-color:  #62b062;
#             color:  #000000;
#         }#T_e2c88_row8_col6{
#             background-color:  #6ab46a;
#             color:  #000000;
#         }#T_e2c88_row9_col0{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_e2c88_row9_col1{
#             background-color:  #71b771;
#             color:  #000000;
#         }#T_e2c88_row9_col3{
#             background-color:  #3a9c3a;
#             color:  #000000;
#         }#T_e2c88_row9_col4{
#             background-color:  #2e972e;
#             color:  #000000;
#         }#T_e2c88_row9_col5,#T_e2c88_row15_col5{
#             background-color:  #4da64d;
#             color:  #000000;
#         }#T_e2c88_row9_col6{
#             background-color:  #3b9d3b;
#             color:  #000000;
#         }#T_e2c88_row10_col0{
#             background-color:  #028102;
#             color:  #f1f1f1;
#         }#T_e2c88_row10_col2{
#             background-color:  #56aa56;
#             color:  #000000;
#         }#T_e2c88_row10_col3{
#             background-color:  #1e8f1e;
#             color:  #000000;
#         }#T_e2c88_row10_col4,#T_e2c88_row11_col1{
#             background-color:  #41a041;
#             color:  #000000;
#         }#T_e2c88_row10_col5{
#             background-color:  #2d962d;
#             color:  #000000;
#         }#T_e2c88_row10_col6,#T_e2c88_row15_col1{
#             background-color:  #319831;
#             color:  #000000;
#         }#T_e2c88_row11_col2,#T_e2c88_row11_col3{
#             background-color:  #45a245;
#             color:  #000000;
#         }#T_e2c88_row11_col5{
#             background-color:  #309730;
#             color:  #000000;
#         }#T_e2c88_row11_col6,#T_e2c88_row14_col5{
#             background-color:  #249224;
#             color:  #000000;
#         }#T_e2c88_row12_col0,#T_e2c88_row13_col4,#T_e2c88_row15_col6{
#             background-color:  #49a449;
#             color:  #000000;
#         }#T_e2c88_row12_col1{
#             background-color:  #3e9e3e;
#             color:  #000000;
#         }#T_e2c88_row12_col3{
#             background-color:  #5dae5d;
#             color:  #000000;
#         }#T_e2c88_row12_col4{
#             background-color:  #55a955;
#             color:  #000000;
#         }#T_e2c88_row12_col5{
#             background-color:  #289428;
#             color:  #000000;
#         }#T_e2c88_row12_col6{
#             background-color:  #289328;
#             color:  #000000;
#         }#T_e2c88_row13_col0{
#             background-color:  #52a852;
#             color:  #000000;
#         }#T_e2c88_row13_col2{
#             background-color:  #73b873;

# %%
ema_strategy = CROSSOVER(close_df, moving_average='Simple', short_window =24, long_window = 90) ## Best drawdown
ema_strategy.generate_signals()

# %%
ema_strategy = CROSSOVER(close_df, moving_average='Simple', short_window =35, long_window = 105) ## Best CAGR
ema_strategy.generate_signals()

# %%
ema_strategy = CROSSOVER(close_df, moving_average='exponential', short_window =19, long_window = 45) ## Best Sharpe
ema_strategy.generate_signals()

# %%
# ema_strategy.data.sample(3).T

# %%
ema_strategy.plot_performance(100)

# %%
ema_strategy.daywise_performance
# Out:
# TotalWins      2166.000000
# TotalLosses    2057.000000
# TotalTrades    4223.000000
# HitRatio          0.510000
# SharpeRatio       0.483220
# CAGR              0.065596
# MaxDrawdown       0.452191
# dtype: float64

# %%
ema_strategy.tradewise_performance
# Out:
# TotalWins           32.0000
# TotalLosses         41.0000
# TotalTrades         73.0000
# HitRatio             0.4384
# AvgWinRet            0.1201
# AvgLossRet          -0.0463
# WinByLossRet         2.5900
# RetVar               0.1233
# NormHitRatio         0.6692
# OptimalTradeSize     0.2216
# dtype: float64

# %%
ema_strategy.yearly_df
# Out:
# <style  type="text/css" >
# #T_d4699_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 50.5%, transparent 50.5%);
#         }#T_d4699_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 18.1%, #ffcccb 18.1%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 18.3%, #ffcccb 18.3%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 78.3%, transparent 78.3%);
#         }#T_d4699_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 55.9%, transparent 55.9%);
#         }#T_d4699_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 78.8%, transparent 78.8%);
#         }#T_d4699_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 57.4%, transparent 57.4%);
#         }#T_d4699_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 62.0%, transparent 62.0%);
#         }#T_d4699_row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 68.0%, transparent 68.0%);
#         }#T_d4699_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.6%, #ffcccb 49.6%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row3_col1,#T_d4699_row3_col2,#T_d4699_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 100.0%, transparent 100.0%);
#         }#T_d4699_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 50.3%, transparent 50.3%);
#         }#T_d4699_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 63.9%, transparent 63.9%);
#         }#T_d4699_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 64.3%, transparent 64.3%);
#         }#T_d4699_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.0%, #ffcccb 37.0%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 70.2%, transparent 70.2%);
#         }#T_d4699_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 59.8%, transparent 59.8%);
#         }#T_d4699_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 52.0%, transparent 52.0%);
#         }#T_d4699_row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 78.6%, transparent 78.6%);
#         }#T_d4699_row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 80.4%, transparent 80.4%);
#         }#T_d4699_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.3%, #ffcccb 43.3%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 73.8%, transparent 73.8%);
#         }#T_d4699_row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 68.5%, transparent 68.5%);
#         }#T_d4699_row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.9%, #ffcccb 12.9%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 53.1%, transparent 53.1%);
#         }#T_d4699_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.1%, #ffcccb 49.1%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 92.7%, transparent 92.7%);
#         }#T_d4699_row9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 92.2%, transparent 92.2%);
#         }#T_d4699_row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.8%, #ffcccb 38.8%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 52.9%, transparent 52.9%);
#         }#T_d4699_row10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.8%, #ffcccb 43.8%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 57.0%, transparent 57.0%);
#         }#T_d4699_row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 28.1%, #ffcccb 28.1%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.7%, #ffcccb 33.7%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #ffcccb 41.9%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 65.5%, transparent 65.5%);
#         }#T_d4699_row12_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 59.0%, transparent 59.0%);
#         }#T_d4699_row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.9%, #ffcccb 38.9%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row13_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.6%, #ffcccb 47.6%, #ffcccb 50.0%, transparent 50.0%);
#         }#T_d4699_row13_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.6%, #ffcccb 38.6%, #ffccc

# %%
class MyClass:
    """A simple example class"""
    i = 12345

    def f(self):
        return 'hello world'

# %%
x = MyClass()

# %%
x.f()
# Out:
# 'hello world'

# %%
 MyClass().f()
# Out:
# 'hello world'

# %%
 MyClass().f()
# Out:
# 'hello world'

# %%
MyClass.i = 10

# %%
MyClass.i
# Out:
# 10

# %%
class myClass:

    def __init__(self, variable1, variable2):

        self.var1 = variable1

        self.var2 = variable2

# %%
 myClass(3, 8).var1
# Out:
# 3

# %%
class Bag:
    def __init__(self):
        self.data = []
    def add(self, x):
        self.data.append(x)
    def addtwice(self, x):
        self.add(x)
        self.add(x)

# %%
x = Bag() 
x.addtwice('ball')

# %%
x.data
# Out:
# ['ball', 'ball']
